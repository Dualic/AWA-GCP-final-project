# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('path-to-file')
df.head(1)
df['travel_index'].plot(kind='hist',bins=4, edgecolor='black', linewidth=1.2)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('path-to-file')
df.head(1)
df['travel_index'].plot(kind='hist',bins=4)
# Out:
# <AxesSubplot:ylabel='Frequency'>
