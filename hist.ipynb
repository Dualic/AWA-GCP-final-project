# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('C:/Users/Henri/Downloads/results-20210916-115748.csv')
df.head(1)
df['travel_index'].plot(kind='hist',bins=4, edgecolor='black', linewidth=1.2)
# Out:
# <AxesSubplot:ylabel='Frequency'>
